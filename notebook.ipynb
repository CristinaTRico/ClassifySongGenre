# %% [markdown]
# Reading and Merging

# %%
import pandas as pd

# Read in track metadata with genre labels
tracks = pd.read_csv('datasets/fma-rock-vs-hiphop.csv')

# Read in track metrics with the features
echonest_metrics = pd.read_json('datasets/echonest-metrics.json', precise_float = True)

# Merge the relevant columns of tracks and echonest_metrics
echo_tracks = echonest_metrics.merge(tracks[['track_id','genre_top']], on="track_id" )

# Inspect the resultant dataframe
echo_tracks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4802 entries, 0 to 4801
# Data columns (total 10 columns):
# track_id            4802 non-null int64
# acousticness        4802 non-null float64
# danceability        4802 non-null float64
# energy              4802 non-null float64
# instrumentalness    4802 non-null float64
# liveness            4802 non-null float64
# speechiness         4802 non-null float64
# tempo               4802 non-null float64
# valence             4802 non-null float64
# genre_top           4802 non-null object
# dtypes: float64(8), int64(1), object(1)
# memory usage: 412.7+ KB

# %% [markdown]
# Explore correlations

# %%
# Create a correlation matrix
corr_metrics = echo_tracks.corr()
corr_metrics.style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_04fc7462_7f3a_11ea_9a14_f45c89961f5frow0_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_04fc7462_7f3a_11ea_9a14_f45c89961f5frow0_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_04fc7462_7f3a_11ea_9a14_f45c89961f5frow0_col2 {
#             background-color:  #d2d2e7;
#             color:  #000000;
#         }    #T_04fc7462_7f3a_11ea_9a14_f45c89961f5frow0_col3 {
#             background-color:  #b5c4df;
#             color:  #000000;
#         }    #T_04fc7462_7f3a_11ea_9a14_f45c89961f5frow0_col4 {
#             background-color:  #f5eef6;
#             color:  #000000;
#         }    #T_04fc7462_7f3a_11ea_9a14_f45c89961f5frow0_col5 {
#             background-color:  #e9e5f1;
#             color:  #000000;
#         }    #T_04fc7462_7f3a_11ea_9a14_f45c89961f5frow0_col6 {
#             background-color:  #d1d2e6;
#             color:  #000000;
#         }    #T_04fc7462_7f3a_11ea_9a14_f45c89961f5frow0_col7 {
#             background-color:  #e1dfed;
#             color:  #000000;
#         }    #T_04fc7462_7f3a_11ea_9a14_f45c89961f5frow0_col8 {
#             background-color:  #dedcec;
#             color:  #000000;
#         }    #T_04fc7462_7f3a_11ea_9a14_f45c89961f5frow1_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_04fc7462_7f3a_11ea_9a14_f45c89961f5frow1_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_04fc7462_7f3a_11ea_9a14_f45c89961f5frow1_col2 {
#             background-color:  #e0dded;
#             color:  #000000;
#         }    #T_04fc7462_7f3a_11ea_9a14_f45c89961f5frow1_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_04fc7462_7f3a_11ea_9a14_f45c89961f5frow1_col4 {
#             background-color:  #97b7d7;
#             color:  #000000;
#         }    #T_04fc7462_7f3a_11ea_9a14_f45c89961f5frow1_col5 {
#             background-color:  #f3edf5;
#             color:  #000000;
#         }    #T_04fc7462_7f3a_11ea_9a14_f45c89961f5frow1_col6 {
#             background-color:  #b8c6e0;
#             color:  #000000;
#         }    #T_04fc7462_7f3a_11ea_9a14_f45c89961f5frow1_col7 {
#             background-color:  #e1dfed;
#             color:  #000000;
#         }    #T_04fc7462_7f3a_11ea_9a14_f45c89961f5frow1_col8 {
#             background-color:  #e2dfee;
#             color:  #000000;
#         }    #T_04fc7462_7f3a_11ea_9a14_f45c89961f5frow2_col0 {
#             background-color:  #bdc8e1;
#             color:  #000000;
#         }    #T_04fc7462_7f3a_11ea_9a14_f45c89961f5frow2_col1 {
#             background-color:  #d0d1e6;
#             color:  #000000;
#         }    #T_04fc7462_7f3a_11ea_9a14_f45c89961f5frow2_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_04fc7462_7f3a_11ea_9a14_f45c89961f5frow2_col3 {
#             background-color:  #fbf3f9;
#             color:  #000000;
#         }    #T_04fc7462_7f3a_11ea_9a14_f45c89961f5frow2_col4 {
#             background-color:  #f3edf5;
#             color:  #000000;
#         }    #T_04fc7462_7f3a_11ea_9a14_f45c89961f5frow2_col5 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_04fc7462_7f3a_11ea_9a14_f45c89961f5frow2_col6 {
#             background-color:  #80aed2;
#             color:  #000000;
#         }    #T_04fc7462_7f3a_11ea_9a14_f45c89961f5frow2_col7 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_04fc7462_7f3a_11ea_9a14_f45c89961f5frow2_col8 {
#             background-color:  #529bc7;
#             color:  #000000;
#         }    #T_04fc7462_7f3a_11ea_9a14_f45c89961f5frow3_col0 {
#             background-color:  #a7bddb;
#             color:  #000000;
#         }    #T_04fc7462_7f3a_11ea_9a14_f45c89961f5frow3_col1 {
#             background-color:  #f5eff6;
#             color:  #000000;
#         }    #T_04fc7462_7f3a_11ea_9a14_f45c89961f5frow3_col2 {
#             background-color:  #fef6fa;
#             color:  #000000;
#         }    #T_04fc7462_7f3a_11ea_9a14_f45c89961f5frow3_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_04fc7462_7f3a_11ea_9a14_f45c89961f5frow3_col4 {
#             background-color:  #c4cbe3;
#             color:  #000000;
#         }    #T_04fc7462_7f3a_11ea_9a14_f45c89961f5frow3_col5 {
#             background-color:  #dcdaeb;
#             color:  #000000;
#         }    #T_04fc7462_7f3a_11ea_9a14_f45c89961f5frow3_col6 {
#             background-color:  #dedcec;
#             color:  #000000;
#         }    #T_04fc7462_7f3a_11ea_9a14_f45c89961f5frow3_col7 {
#             background-color:  #adc1dd;
#             color:  #000000;
#         }    #T_04fc7462_7f3a_11ea_9a14_f45c89961f5frow3_col8 {
#             background-color:  #d9d8ea;
#             color:  #000000;
#         }    #T_04fc7462_7f3a_11ea_9a14_f45c89961f5frow4_col0 {
#             background-color:  #f4eef6;
#             color:  #000000;
#         }    #T_04fc7462_7f3a_11ea_9a14_f45c89961f5frow4_col1 {
#             background-color:  #97b7d7;
#             color:  #000000;
#         }    #T_04fc7462_7f3a_11ea_9a14_f45c89961f5frow4_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_04fc7462_7f3a_11ea_9a14_f45c89961f5frow4_col3 {
#             background-color:  #d2d3e7;
#             color:  #000000;
#         }    #T_04fc7462_7f3a_11ea_9a14_f45c89961f5frow4_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_04fc7462_7f3a_11ea_9a14_f45c89961f5frow4_col5 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_04fc7462_7f3a_11ea_9a14_f45c89961f5frow4_col6 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_04fc7462_7f3a_11ea_9a14_f45c89961f5frow4_col7 {
#             background-color:  #d9d8ea;
#             color:  #000000;
#         }    #T_04fc7462_7f3a_11ea_9a14_f45c89961f5frow4_col8 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_04fc7462_7f3a_11ea_9a14_f45c89961f5frow5_col0 {
#             background-color:  #bdc8e1;
#             color:  #000000;
#         }    #T_04fc7462_7f3a_11ea_9a14_f45c89961f5frow5_col1 {
#             background-color:  #ced0e6;
#             color:  #000000;
#         }    #T_04fc7462_7f3a_11ea_9a14_f45c89961f5frow5_col2 {
#             background-color:  #ede8f3;
#             color:  #000000;
#         }    #T_04fc7462_7f3a_11ea_9a14_f45c89961f5frow5_col3 {
#             background-color:  #bdc8e1;
#             color:  #000000;
#         }    #T_04fc7462_7f3a_11ea_9a14_f45c89961f5frow5_col4 {
#             background-color:  #dbdaeb;
#             color:  #000000;
#         }    #T_04fc7462_7f3a_11ea_9a14_f45c89961f5frow5_col5 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_04fc7462_7f3a_11ea_9a14_f45c89961f5frow5_col6 {
#             background-color:  #c0c9e2;
#             color:  #000000;
#         }    #T_04fc7462_7f3a_11ea_9a14_f45c89961f5frow5_col7 {
#             background-color:  #dcdaeb;
#             color:  #000000;
#         }    #T_04fc7462_7f3a_11ea_9a14_f45c89961f5frow5_col8 {
#             background-color:  #e8e4f0;
#             color:  #000000;
#         }    #T_04fc7462_7f3a_11ea_9a14_f45c89961f5frow6_col0 {
#             background-color:  #d0d1e6;
#             color:  #000000;
#         }    #T_04fc7462_7f3a_11ea_9a14_f45c89961f5frow6_col1 {
#             background-color:  #b8c6e0;
#             color:  #000000;
#         }    #T_04fc7462_7f3a_11ea_9a14_f45c89961f5frow6_col2 {
#             background-color:  #93b5d6;
#             color:  #000000;
#         }    #T_04fc7462_7f3a_11ea_9a14_f45c89961f5frow6_col3 {
#             background-color:  #eae6f1;
#             color:  #000000;
#         }    #T_04fc7462_7f3a_11ea_9a14_f45c89961f5frow6_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_04fc7462_7f3a_11ea_9a14_f45c89961f5frow6_col5 {
#             background-color:  #eae6f1;
#             color:  #000000;

# %% [markdown]
# Normaliz Feature Data

# %%
# Define our features 
features = echo_tracks.drop(columns=['genre_top','track_id'])

# Define our labels
labels = echo_tracks['genre_top']

# Import the StandardScaler
from sklearn.preprocessing import StandardScaler

# Scale the features and set the values to a new variable
scaler = StandardScaler()
scaled_train_features = scaler.fit_transform(features)
